# %%
#Imports
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Getting the dataset
# !git clone https://github.com/alexeygrigorev/clothing-dataset-small.git ../data/raw/clothing-dataset-small/
# Out:
# fatal: destination path '../data/raw/clothing-dataset-small' already exists and is not an empty directory.

# %%
train_path = '../data/raw/clothing-dataset-small/train/'
val_path = '../data/raw/clothing-dataset-small/validation/'
test_path = '../data/raw/clothing-dataset-small/test/'

# %%
import glob
from PIL import Image
import random
clothing_list = glob.glob('../data/raw/clothing-dataset-small/train/**/*.*', recursive=True)
Image.open(random.choice(clothing_list))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=400x533 at 0x7F389C115040>

# %%
# !pip install deepfeatx --quiet

# %%
from deepfeatx.image import ImageFeatureExtractor

# %%
fe = ImageFeatureExtractor()

# %%
df = fe.extract_features_from_directory(train_path,
                                   classes_as_folders=True,
                                   export_class_names=True)
# Out:
# Found 3068 images belonging to 10 classes.
# 96/96 [==============================] - 14s 116ms/step

# %%
val = fe.extract_features_from_directory(val_path,
                                   classes_as_folders=True,
                                   export_class_names=True)
# Out:
# Found 341 images belonging to 10 classes.
# 11/11 [==============================] - 2s 169ms/step

# %%
test = fe.extract_features_from_directory(test_path,
                                   classes_as_folders=True,
                                   export_class_names=True)
# Out:
# Found 372 images belonging to 10 classes.
# 12/12 [==============================] - 2s 156ms/step

# %%
df.head()
# Out:
#                                            filepaths classes         0  \
# 0  ../data/raw/clothing-dataset-small/train/dress...   dress  0.042460
# 1  ../data/raw/clothing-dataset-small/train/dress...   dress  0.025774
# 2  ../data/raw/clothing-dataset-small/train/dress...   dress  0.051302
# 3  ../data/raw/clothing-dataset-small/train/dress...   dress  0.022691
# 4  ../data/raw/clothing-dataset-small/train/dress...   dress  0.231369
#
#           1         2         3         4         5         6         7  ...  \
# 0  1.875373  0.000000  2.060594  0.433915  0.005656  0.026123  0.333477  ...
# 1  0.953888  0.336730  0.000000  0.025267  0.212971  0.074700  0.000000  ...
# 2  4.518892  0.000000  0.330943  0.476871  0.046683  0.606202  0.479695  ...
# 3  0.481851  0.146194  0.000000  0.020019  0.288917  0.528621  0.008216  ...
# 4  2.579861  0.157428  0.628241  2.256970  0.084941  0.744962  0.094804  ...
#
#        2038      2039      2040      2041      2042      2043      2044  \
# 0  0.307839  1.056877  0.000000  0.003265  0.000000  0.000000  0.027121
# 1  0.059057  0.204012  0.000000  0.103856  0.182376  0.446977  0.000228
# 2  1.242172  0.000000  0.582222  0.000000  0.000000  0.119602  0.013267
# 3  1.658859  0.004760  0.000000  0.003752  0.002769  0.065090  0.065709
# 4  0.172142  0.131973  0.050736  0.010276  0.122933  0.329143  1.164254
#
#        2045      2046      2047
# 0  0.436055  0.000000  0.390338
# 1  1.121514  0.143794  1.256672
# 2  0.004082  0.166753  0.233876
# 3  0.077569  0.362168  0.592691
# 4  1.709702  0.189396  3.573076
#
# [5 rows x 2050 columns]

# %%
df.shape
# Out:
# (3068, 2050)

# %%
#Exportando para csv
df.to_csv('../data/processed_data.csv', index=False)
test.to_csv('../data/processed_test.csv', index=False)

# %%
#opening the file
df = pd.read_csv('../data/processed_data.csv')
test = pd.read_csv('../data/processed_test.csv')

# %%
X_train = df.drop(['filepaths', 'classes'], axis=1)
y_train = df['classes']

# %%
X_test = test.drop(['filepaths', 'classes'], axis=1)
y_test = test['classes']

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression(max_iter=10000, random_state=42)
lr.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=10000, random_state=42)

# %%
lr.score(X_test, y_test)
# Out:
# 0.8924731182795699

# %%
from sklearn.metrics import classification_report

# %%
y_pred = lr.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        dress       0.93      0.87      0.90        15
#          hat       1.00      0.92      0.96        12
#   longsleeve       0.85      0.85      0.85        72
#      outwear       0.89      0.84      0.86        38
#        pants       0.93      0.98      0.95        42
#        shirt       0.71      0.65      0.68        26
#        shoes       1.00      0.99      0.99        73
#       shorts       0.87      0.90      0.89        30
#        skirt       0.85      0.92      0.88        12
#      t-shirt       0.85      0.90      0.88        52
#
#     accuracy                           0.89       372
#    macro avg       0.89      0.88      0.88       372
# weighted avg       0.89      0.89      0.89       372

# %%
from catboost import CatBoostClassifier
cb = CatBoostClassifier(task_type='GPU', one_hot_max_size=255, logging_level='Silent')
cb.fit(X_train, y_train)

# %%
cb.score(X_test, y_test)
# Out:
# 0.8629032258064516

# %%
y_pred_cb = cb.predict(X_test)
print(classification_report(y_test, y_pred_cb))
# Out:
#               precision    recall  f1-score   support
#
#        dress       0.79      0.73      0.76        15
#          hat       1.00      0.92      0.96        12
#   longsleeve       0.81      0.78      0.79        72
#      outwear       0.83      0.79      0.81        38
#        pants       0.95      0.98      0.96        42
#        shirt       0.58      0.58      0.58        26
#        shoes       1.00      0.99      0.99        73
#       shorts       0.90      0.87      0.88        30
#        skirt       0.92      0.92      0.92        12
#      t-shirt       0.80      0.92      0.86        52
#
#     accuracy                           0.86       372
#    macro avg       0.86      0.85      0.85       372
# weighted avg       0.86      0.86      0.86       372

# %%
directory = '../models'
if not os.path.exists(directory):
    os.makedirs(directory)
import pickle
pickle.dump(lr, open('../models/logistic_regression.pkl', 'wb'))

# %%
import pickle
model = pickle.load(open('../models/logistic_regression.pkl', 'rb'))

# %%
model.classes_

# %%
import gradio as gr
from PIL import Image
def recognize_clothing(img):
    #img=Image.fromarray(img)
    vector = fe.img_to_vector(img)
    label = lr.predict(vector)
    confidence = lr.predict_proba(vector)
    return label[0], confidence[0]

# %%
clothing_list = glob.glob('../data/raw/clothing-dataset-small/train/**/*.*', recursive=True)
img=Image.open(random.choice(clothing_list))
img

# %%
vector = fe.img_to_vector(img)

# %%
recognize_clothing(img)

# %%
gr.Interface(fn=recognize_clothing, inputs="image", outputs="text").launch(debug=True)
